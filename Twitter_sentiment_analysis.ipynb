# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import tweepy

# %%
consumer_key = 'KEz4cAwsZw0AAwoeuKlItIefx'
consumer_secret_key = 'fYzAZTZUDQMsG4pKLJOILZGTWWUPkiodyoN3kGvT1u0EkPKAoT'
access_token='2585022120-heth3THjSYeN1lN5GyCYxcoscaY1TKt2BoVUmlg'
access_token_secret='0sDWR0VglHvy6IhVqQRec7xVZGZYmvJZhTqH3SR22WkOw'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

tweets = api.search('Apple Watch', count=200)

# %%
type(tweets)
# Out:
# tweepy.models.SearchResults

# %%
print(tweets[0].created_at)
# Out:
# 2019-03-20 04:45:05

# %%
#convert it to a dataframe
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
data.head()
# Out:
#                                               Tweets
# 0  RT @defjam: .@TEYANATAYLOR's streams are boomi...
# 1  RT @itzyygomez: Apple Watch fuck you for makin...
# 2  **New episode!!**\nWe watch and discuss the 19...
# 3  My Apple Watch got stolen at the concert but I...
# 4  NEW iMac i9 - Apple You're Drunk, Go Home. A B...

# %%
import nltk
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
listy=[]

for index, row in data.iterrows():
  score = sia.polarity_scores(row['Tweets'])
  listy.append(score)

se = pd.Series(listy)  
data['Polarity'] = se.values

data.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                               Tweets  \
# 0  RT @defjam: .@TEYANATAYLOR's streams are boomi...
# 1  RT @itzyygomez: Apple Watch fuck you for makin...
# 2  **New episode!!**\nWe watch and discuss the 19...
# 3  My Apple Watch got stolen at the concert but I...
# 4  NEW iMac i9 - Apple You're Drunk, Go Home. A B...
#
#                                             Polarity
# 0  {'neg': 0.101, 'neu': 0.79, 'pos': 0.109, 'com...
# 1  {'neg': 0.216, 'neu': 0.657, 'pos': 0.127, 'co...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.076, 'neu': 0.791, 'pos': 0.133, 'co...
# 4  {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'comp...

# %%
print(data['Polarity'][20])
print(data['Tweets'][20])
# Out:
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.69}
# RT @chefjoseandres: A simple apple is much more...it is a symbol of hope! 🍎 “All of us that have lived in Venezuela know what it’s like to…

# %%
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @defjam: .@TEYANATAYLOR's streams are boomi...
# 1   RT @itzyygomez: Apple Watch fuck you for makin...
# 2   **New episode!!**\nWe watch and discuss the 19...
# 3   My Apple Watch got stolen at the concert but I...
# 4   NEW iMac i9 - Apple You're Drunk, Go Home. A B...
# 5   NEW iMac i9 - Apple You're Drunk, Go Home. A B...
# 6   RT @batsuina: ソニーミュージック × アニプレックスが贈る『 バンドやろうぜ！...
# 7                           @kazuya2418 Apple Watch❣️
# 8   RT @AmaAmaLeeLee: My English cover of Colors f...
# 9      RT @dudaahh_maria: Queria tanto um Apple Watch
# 10  RT @claboratoryscom: TANAKA ALICEの新曲「Watch Out...
# 11  RT @vic_thor: @writerinthedark It happens to m...
# 12  RT @pitchfork: A rare transmission from Fiona ...
# 13  インドのりんご風味鳥から揚げの作り方 / Chicken Apple Gravy https...
# 14  @ConsumerCourt_ I am a victim of fraud by @Fli...
# 15  TANAKA ALICEの新曲「Watch Out!」のジャケットアートを菊地絢女アート作品...
# ...
